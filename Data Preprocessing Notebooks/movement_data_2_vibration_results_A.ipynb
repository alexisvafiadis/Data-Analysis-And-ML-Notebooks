# %% [markdown]
# # II - Visualization of movement data processing

# %% [markdown]
# This notebook is a **continuation** of the **movement_data_1_processing** notebook, aimed at visualizing an important step. The cells were first executed in the previous notebook and then copied here to keep the file size smaller

# %% [markdown]
# ## Identification process of GPS vibration points

# %% [markdown]
# This uses data from a process that happened before the filtering of trajectories covering too small an area, which is why even very short / compact trajectories have been kept.

# %% [markdown]
# ## Type A

# %%
di = DATAINFO(data_kind_a,0,0,reference_timestamp,id_col='ID_equipment',anonyme=True, year=2024)

# %%
pl.plot_trajectories_auto_old(1,1,di, showvib=True)
# Out:
# List of selected equipment :
# [1]

# %%
pl.plot_trajectories_auto_old(1,2,di, showvib=True)
# Out:
# List of selected equipment :
# [1, 38]

# %%
pl.plot_trajectories_auto_old(1,3,di, showvib=True)
# Out:
# List of selected equipment :
# [1]

# %%
pl.plot_trajectories_auto_old(1,4,di, showvib=True)
# Out:
# List of selected equipment :
# [1]

# %%
pl.plot_trajectories_auto_old(1,5,di, showvib=True)
# Out:
# List of selected equipment :
# [1, 38]

# %%
pl.plot_trajectories_auto_old(1,6,di, showvib=True)
# Out:
# List of selected equipment :
# [1, 38]

# %%
pl.plot_trajectories_auto_old(1,7,di, showvib=True)
# Out:
# List of selected equipment :
# [1]

# %%
pl.plot_trajectories_auto_old(1,8,di, showvib=True)
# Out:
# List of selected equipment :
# [1]

# %%
pl.plot_trajectories_auto_old(1,9,di, showvib=True)

# %%
pl.plot_trajectories_auto_old(1,10,di, showvib=True)
# Out:
# List of selected equipment :
# [1, 14, 21, 99]

# %%
pl.plot_trajectories_auto_old(1,11,di, showvib=True)
# Out:
# List of selected equipment :
# [1, 14, 21, 99]

# %%
pl.plot_trajectories_auto_old(1,12,di, showvib=True)
# Out:
# List of selected equipment :
# [1, 14, 21]

# %%
pl.plot_trajectories_auto_old(1,13,di, showvib=True)
# Out:
# List of selected equipment :
# [1, 14, 21]

# %%
pl.plot_trajectories_auto_old(1,14,di, showvib=True)
# Out:
# List of selected equipment :
# [1, 14, 21]
